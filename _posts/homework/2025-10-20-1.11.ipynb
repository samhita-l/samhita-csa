// %% [raw]
// ---
// title: Math Class
// comments: true
// layout: post
// permalink: /lesson114
// description: Math Class
// author: Samhita Lagisetti
// ---

// %% [markdown]
// Popcorn Hack #1: Power Level Calculator

// %%
// Popcorn Hack #1: Power Level Calculator
public class PowerCalculator {
    public static void main(String[] args) {
        int level = 10; // or prompt user input if desired
        double basePower = 100;
        double finalPower = basePower * Math.pow(1.2, level);

        System.out.println("Level: " + level);
        System.out.println("Base Power: " + (int) basePower);
        System.out.printf("Final Power: %.2f%n", finalPower);
    }
}

PowerCalculator.main(null);
// Out:
// Level: 10
// Base Power: 100
// Final Power: 619.17

// %% [markdown]
// Popcorn Hack 2

// %%
// Popcorn Hack #2: Loot Drop Simulator
public class LootDropSimulator {
    public static void main(String[] args) {
        int rarityRoll = (int)(Math.random() * 100) + 1;

        String rarity;
        int goldMin = 0;
        int goldMax = 0;

        if (rarityRoll <= 60) {
            rarity = "COMMON";
            goldMin = 10;
            goldMax = 30;
        } else if (rarityRoll <= 85) {
            rarity = "RARE";
            goldMin = 31;
            goldMax = 70;
        } else {
            rarity = "LEGENDARY";
            goldMin = 71;
            goldMax = 100;
        }

        int goldValue = (int)(Math.random() * (goldMax - goldMin + 1)) + goldMin;

        System.out.println("Loot Drop!");
        System.out.println("Rarity Roll: " + rarityRoll);
        System.out.println("You got: " + rarity + " item");
        System.out.println("Gold Value: " + goldValue);
    }
}

LootDropSimulator.main(null);
// Out:
// Loot Drop!
// Rarity Roll: 41
// You got: COMMON item
// Gold Value: 27
